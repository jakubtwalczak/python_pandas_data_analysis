# %%
import pandas as pd
import numpy as np

animals = pd.read_csv('sleep_time.csv',
                      index_col='ID')
animals.head()
# Out:
#                           name       genus   vore         order  conservation  \
# ID
# 1                      Cheetah    Acinonyx  carni     Carnivora            lc
# 2                   Owl monkey       Aotus   omni      Primates           NaN
# 3              Mountain beaver  Aplodontia  herbi      Rodentia            nt
# 4   Greater short-tailed shrew     Blarina   omni  Soricomorpha            lc
# 5                          Cow         Bos  herbi  Artiodactyla  domesticated
#
#     sleep_total  sleep_rem  sleep_cycle  awake  brainwt   bodywt
# ID
# 1          12.1        NaN          NaN   11.9      NaN   50.000
# 2          17.0        1.8          NaN    7.0  0.01550    0.480
# 3          14.4        2.4          NaN    9.6      NaN    1.350
# 4          14.9        2.3     0.133333    9.1  0.00029    0.019
# 5           4.0        0.7     0.666667   20.0  0.42300  600.000

# %%
animals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83 entries, 1 to 83
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          83 non-null     object
#  1   genus         83 non-null     object
#  2   vore          76 non-null     object
#  3   order         83 non-null     object
#  4   conservation  54 non-null     object
#  5   sleep_total   83 non-null     float64
#  6   sleep_rem     61 non-null     float64
#  7   sleep_cycle   32 non-null     float64
#  8   awake         83 non-null     float64
#  9   brainwt       56 non-null     float64
#  10  bodywt        83 non-null     float64
# dtypes: float64(6), object(5)
# memory usage: 7.8+ KB

# %%
herbi = animals.where(animals['vore'] == 'herbi')
herbi.head()
# Out:
#                name       genus   vore         order  conservation  \
# ID
# 1               NaN         NaN    NaN           NaN           NaN
# 2               NaN         NaN    NaN           NaN           NaN
# 3   Mountain beaver  Aplodontia  herbi      Rodentia            nt
# 4               NaN         NaN    NaN           NaN           NaN
# 5               Cow         Bos  herbi  Artiodactyla  domesticated
#
#     sleep_total  sleep_rem  sleep_cycle  awake  brainwt  bodywt
# ID
# 1           NaN        NaN          NaN    NaN      NaN     NaN
# 2           NaN        NaN          NaN    NaN      NaN     NaN
# 3          14.4        2.4          NaN    9.6      NaN    1.35
# 4           NaN        NaN          NaN    NaN      NaN     NaN
# 5           4.0        0.7     0.666667   20.0    0.423  600.00

# %%
herbi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83 entries, 1 to 83
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          32 non-null     object
#  1   genus         32 non-null     object
#  2   vore          32 non-null     object
#  3   order         32 non-null     object
#  4   conservation  26 non-null     object
#  5   sleep_total   32 non-null     float64
#  6   sleep_rem     24 non-null     float64
#  7   sleep_cycle   12 non-null     float64
#  8   awake         32 non-null     float64
#  9   brainwt       20 non-null     float64
#  10  bodywt        32 non-null     float64
# dtypes: float64(6), object(5)
# memory usage: 7.8+ KB

# %%
herbi.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 5 to 77
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          10 non-null     object
#  1   genus         10 non-null     object
#  2   vore          10 non-null     object
#  3   order         10 non-null     object
#  4   conservation  10 non-null     object
#  5   sleep_total   10 non-null     float64
#  6   sleep_rem     10 non-null     float64
#  7   sleep_cycle   10 non-null     float64
#  8   awake         10 non-null     float64
#  9   brainwt       10 non-null     float64
#  10  bodywt        10 non-null     float64
# dtypes: float64(6), object(5)
# memory usage: 960.0+ bytes

# %%
carni = animals.where(animals['vore'] == 'carni')
carni.head()
# Out:
#        name     genus   vore      order conservation  sleep_total  sleep_rem  \
# ID
# 1   Cheetah  Acinonyx  carni  Carnivora           lc         12.1        NaN
# 2       NaN       NaN    NaN        NaN          NaN          NaN        NaN
# 3       NaN       NaN    NaN        NaN          NaN          NaN        NaN
# 4       NaN       NaN    NaN        NaN          NaN          NaN        NaN
# 5       NaN       NaN    NaN        NaN          NaN          NaN        NaN
#
#     sleep_cycle  awake  brainwt  bodywt
# ID
# 1           NaN   11.9      NaN    50.0
# 2           NaN    NaN      NaN     NaN
# 3           NaN    NaN      NaN     NaN
# 4           NaN    NaN      NaN     NaN
# 5           NaN    NaN      NaN     NaN

# %%
carni.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83 entries, 1 to 83
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          19 non-null     object
#  1   genus         19 non-null     object
#  2   vore          19 non-null     object
#  3   order         19 non-null     object
#  4   conservation  14 non-null     object
#  5   sleep_total   19 non-null     float64
#  6   sleep_rem     10 non-null     float64
#  7   sleep_cycle   5 non-null      float64
#  8   awake         19 non-null     float64
#  9   brainwt       9 non-null      float64
#  10  bodywt        19 non-null     float64
# dtypes: float64(6), object(5)
# memory usage: 7.8+ KB

# %%
carni.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 9 to 28
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          3 non-null      object
#  1   genus         3 non-null      object
#  2   vore          3 non-null      object
#  3   order         3 non-null      object
#  4   conservation  3 non-null      object
#  5   sleep_total   3 non-null      float64
#  6   sleep_rem     3 non-null      float64
#  7   sleep_cycle   3 non-null      float64
#  8   awake         3 non-null      float64
#  9   brainwt       3 non-null      float64
#  10  bodywt        3 non-null      float64
# dtypes: float64(6), object(5)
# memory usage: 288.0+ bytes

# %%
omni = animals.where(animals['vore'] == 'omni')
omni.head()
# Out:
#                           name    genus  vore         order conservation  \
# ID
# 1                          NaN      NaN   NaN           NaN          NaN
# 2                   Owl monkey    Aotus  omni      Primates          NaN
# 3                          NaN      NaN   NaN           NaN          NaN
# 4   Greater short-tailed shrew  Blarina  omni  Soricomorpha           lc
# 5                          NaN      NaN   NaN           NaN          NaN
#
#     sleep_total  sleep_rem  sleep_cycle  awake  brainwt  bodywt
# ID
# 1           NaN        NaN          NaN    NaN      NaN     NaN
# 2          17.0        1.8          NaN    7.0  0.01550   0.480
# 3           NaN        NaN          NaN    NaN      NaN     NaN
# 4          14.9        2.3     0.133333    9.1  0.00029   0.019
# 5           NaN        NaN          NaN    NaN      NaN     NaN

# %%
omni.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83 entries, 1 to 83
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          20 non-null     object
#  1   genus         20 non-null     object
#  2   vore          20 non-null     object
#  3   order         20 non-null     object
#  4   conservation  9 non-null      object
#  5   sleep_total   20 non-null     float64
#  6   sleep_rem     18 non-null     float64
#  7   sleep_cycle   11 non-null     float64
#  8   awake         20 non-null     float64
#  9   brainwt       17 non-null     float64
#  10  bodywt        20 non-null     float64
# dtypes: float64(6), object(5)
# memory usage: 7.8+ KB

# %%
omni.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 4 to 74
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          5 non-null      object
#  1   genus         5 non-null      object
#  2   vore          5 non-null      object
#  3   order         5 non-null      object
#  4   conservation  5 non-null      object
#  5   sleep_total   5 non-null      float64
#  6   sleep_rem     5 non-null      float64
#  7   sleep_cycle   5 non-null      float64
#  8   awake         5 non-null      float64
#  9   brainwt       5 non-null      float64
#  10  bodywt        5 non-null      float64
# dtypes: float64(6), object(5)
# memory usage: 480.0+ bytes

# %%
animals.groupby('vore')['sleep_total'].mean()
# Out:
# vore
# carni      10.378947
# herbi       9.509375
# insecti    14.940000
# omni       10.925000
# Name: sleep_total, dtype: float64

# %%
animals.query('sleep_total > 14')
# Out:
#                               name         genus     vore            order  \
# ID
# 2                       Owl monkey         Aotus     omni         Primates
# 3                  Mountain beaver    Aplodontia    herbi         Rodentia
# 4       Greater short-tailed shrew       Blarina     omni     Soricomorpha
# 6                 Three-toed sloth      Bradypus    herbi           Pilosa
# 18            Long-nosed armadillo       Dasypus    carni        Cingulata
# 20          North American Opossum     Didelphis     omni  Didelphimorphia
# 22                   Big brown bat     Eptesicus  insecti       Chiroptera
# 27       Western american chipmunk      Eutamias    herbi         Rodentia
# 37            Thick-tailed opposum    Lutreolina    carni  Didelphimorphia
# 39                Mongolian gerbil      Meriones    herbi         Rodentia
# 40                  Golden hamster  Mesocricetus    herbi         Rodentia
# 43                Little brown bat        Myotis  insecti       Chiroptera
# 44            Round-tailed muskrat      Neofiber    herbi         Rodentia
# 47      Northern grasshopper mouse     Onychomys    carni         Rodentia
# 51                           Tiger      Panthera    carni        Carnivora
# 62                 Giant armadillo    Priodontes  insecti        Cingulata
# 70          Arctic ground squirrel  Spermophilus    herbi         Rodentia
# 72  Golden-mantled ground squirrel  Spermophilus    herbi         Rodentia
# 76       Eastern american chipmunk        Tamias    herbi         Rodentia
# 78                          Tenrec        Tenrec     omni     Afrosoricida
#
#    conservation  sleep_total  sleep_rem  sleep_cycle  awake  brainwt   bodywt
# ID
# 2           NaN         17.0        1.8          NaN    7.0  0.01550    0.480
# 3            nt         14.4        2.4          NaN    9.6      NaN    1.350
# 4            lc         14.9        2.3     0.133333    9.1  0.00029    0.019
# 6           NaN         14.4        2.2     0.766667    9.6      NaN    3.850
# 18           lc         17.4        3.1     0.383333    6.6  0.01080    3.500
# 20           lc         18.0        4.9     0.333333    6.0  0.00630    1.700
# 22           lc         19.7        3.9     0.116667    4.3  0.00030    0.023
# 27          NaN         14.9        NaN          NaN    9.1      NaN    0.071
# 37           lc         19.4        6.6          NaN    4.6      NaN    0.370
# 39           lc         14.2        1.9          NaN    9.8      NaN    0.053
# 40           en         14.3        3.1     0.200000    9.7  0.00100    0.120
# 43          NaN         19.9        2.0     0.200000    4.1  0.00025    0.010
# 44           nt         14.6        NaN          NaN    9.4      NaN    0.266
# 47           lc         14.5        NaN          NaN    9.5      NaN    0.028
# 51           en         15.8        NaN          NaN    8.2      NaN  162.564
# 62           en         18.1        6.1          NaN    5.9  0.08100   60.000
# 70           lc         16.6        NaN          NaN    7.4  0.00570    0.920
# 72           lc         15.9        3.0          NaN    8.1      NaN    0.205
# 76          NaN         15.8        NaN          NaN    8.2      NaN    0.112
# 78          NaN         15.6        2.3          NaN    8.4  0.00260    0.900

# %%
animals.query('sleep_total > 14 and vore == "herbi"')
# Out:
#                               name         genus   vore     order  \
# ID
# 3                  Mountain beaver    Aplodontia  herbi  Rodentia
# 6                 Three-toed sloth      Bradypus  herbi    Pilosa
# 27       Western american chipmunk      Eutamias  herbi  Rodentia
# 39                Mongolian gerbil      Meriones  herbi  Rodentia
# 40                  Golden hamster  Mesocricetus  herbi  Rodentia
# 44            Round-tailed muskrat      Neofiber  herbi  Rodentia
# 70          Arctic ground squirrel  Spermophilus  herbi  Rodentia
# 72  Golden-mantled ground squirrel  Spermophilus  herbi  Rodentia
# 76       Eastern american chipmunk        Tamias  herbi  Rodentia
#
#    conservation  sleep_total  sleep_rem  sleep_cycle  awake  brainwt  bodywt
# ID
# 3            nt         14.4        2.4          NaN    9.6      NaN   1.350
# 6           NaN         14.4        2.2     0.766667    9.6      NaN   3.850
# 27          NaN         14.9        NaN          NaN    9.1      NaN   0.071
# 39           lc         14.2        1.9          NaN    9.8      NaN   0.053
# 40           en         14.3        3.1     0.200000    9.7   0.0010   0.120
# 44           nt         14.6        NaN          NaN    9.4      NaN   0.266
# 70           lc         16.6        NaN          NaN    7.4   0.0057   0.920
# 72           lc         15.9        3.0          NaN    8.1      NaN   0.205
# 76          NaN         15.8        NaN          NaN    8.2      NaN   0.112

# %%
animals.query('sleep_total > 14 and vore == "herbi" and bodywt > 1')
# Out:
#                 name       genus   vore     order conservation  sleep_total  \
# ID
# 3    Mountain beaver  Aplodontia  herbi  Rodentia           nt         14.4
# 6   Three-toed sloth    Bradypus  herbi    Pilosa          NaN         14.4
#
#     sleep_rem  sleep_cycle  awake  brainwt  bodywt
# ID
# 3         2.4          NaN    9.6      NaN    1.35
# 6         2.2     0.766667    9.6      NaN    3.85
